# %%
N, K = map(int, input().split())
A = list(map(int, input().split()))
for _ in range(K):
    A.pop(0)
    A.append(0)
    
print(*A)

# %%
H, M = map(int, input().split())
def kakunin(H, M):
    check = True
    if int(H[0]) <= 1:
        if int(H[1]) >= 6:
            check = False

    else:
        if int(H[1]) >= 6:
            check = False
        if int(M[0]) >= 4:
            check = False
    return check

while True:
    if H <= 9:
        H = "0" + str(H)
    else:
        H = str(H)
    if M <= 9:
        M = "0" + str(M)
    else:
        M = str(M)
    print(H, M)
    if kakunin(H, M):
        H = int(H)
        M = int(M)
        print(H, M)
        break
    else:
        H = int(H)
        M = int(M)
        if M < 59:
            M += 1
        else:
            if H < 23:
                M = 0
                H += 1
            else:
                M = 0
                H = 0
# Out:
# 00 03
# 00 03
# 0 3

# %%
def kakunin(H, M):
    check = True
    if int(H[0]) <= 1:
        if int(H[1]) >= 6:
            check = False

    else:
        if int(H[1]) >= 6:
            check = False
        if int(M[0]) >= 4:
            check = False
    return check
for h in range(60):
    for m in range(60):
        H = h
        M = m
        while True:
            if H <= 9:
                H = "0" + str(H)
            else:
                H = str(H)
            if M <= 9:
                M = "0" + str(M)
            else:
                M = str(M)
            print(H, M)
            if kakunin(H, M):
                H = int(H)
                M = int(M)
                print(H, M)
                break
            else:
                H = int(H)
                M = int(M)
                if M < 59:
                    M += 1
                else:
                    if H < 23:
                        M = 0
                        H += 1
                    else:
                        M = 0
                        H = 0
# Out:
# 00 00
# 0 0
# 00 01
# 0 1
# 00 02
# 0 2
# 00 03
# 0 3
# 00 04
# 0 4
# 00 05
# 0 5
# 00 06
# 0 6
# 00 07
# 0 7
# 00 08
# 0 8
# 00 09
# 0 9
# 00 10
# 0 10
# 00 11
# 0 11
# 00 12
# 0 12
# 00 13
# 0 13
# 00 14
# 0 14
# 00 15
# 0 15
# 00 16
# 0 16
# 00 17
# 0 17
# 00 18
# 0 18
# 00 19
# 0 19
# 00 20
# 0 20
# 00 21
# 0 21
# 00 22
# 0 22
# 00 23
# 0 23
# 00 24
# 0 24
# 00 25
# 0 25
# 00 26
# 0 26
# 00 27
# 0 27
# 00 28
# 0 28
# 00 29
# 0 29
# 00 30
# 0 30
# 00 31
# 0 31
# 00 32
# 0 32
# 00 33
# 0 33
# 00 34
# 0 34
# 00 35
# 0 35
# 00 36
# 0 36
# 00 37
# 0 37
# 00 38
# 0 38
# 00 39
# 0 39
# 00 40
# 0 40
# 00 41
# 0 41
# 00 42
# 0 42
# 00 43
# 0 43
# 00 44
# 0 44
# 00 45
# 0 45
# 00 46
# 0 46
# 00 47
# 0 47
# 00 48
# 0 48
# 00 49
# 0 49
# 00 50
# 0 50
# 00 51
# 0 51
# 00 52
# 0 52
# 00 53
# 0 53
# 00 54
# 0 54
# 00 55
# 0 55
# 00 56
# 0 56
# 00 57
# 0 57
# 00 58
# 0 58
# 00 59
# 0 59
# 01 00
# 1 0
# 01 01
# 1 1
# 01 02
# 1 2
# 01 03
# 1 3
# 01 04
# 1 4
# 01 05
# 1 5
# 01 06
# 1 6
# 01 07
# ...
