# %%
n = int(input())
p_list = [*map(int, input().split())]
max_p = max(p_list)
ans = max_p - p_list[0]
if p_list[0] != max_p:
    print(ans+1)
elif p_list.count(max_p) >= 2:
    print(1)
else:
    print(0)
# Out:
# 4
# 5 15 2 10
# 10

# %%
n, m = map(int, input().split())
n_list = [i for i in range(1, n+1)]
for i in range(m):
    a, b = map(int, input().split())
    if b in n_list:
        n_list.remove(b)
if len(n_list) == 1:
    print(n_list[0])
else:
    print(-1)
# Out:
# 2 3
# [1, 2]

# %%
n = int(input())
a_list = [*map(int, input().split())]
count = 0
ans = [0 for _ in range(n)]
def get_max_two(l):
    # リストを降順にソートして最も大きな値と2番目に大きな値を取得
    sorted_list = sorted(l, reverse=True)
    max_value = sorted_list[0]
    second_max_value = sorted_list[1]
    return max_value, second_max_value

def get_min_two(l):
    # リストを昇順にソートして最も小さな値と2番目に小さな値を取得
    sorted_list = sorted(l)
    min_value = sorted_list[0]
    second_min_value = sorted_list[1]
    return min_value, second_min_value


while True:
    print(a_list)
    max1, max2 = get_max_two(a_list)
    min1, min2 = get_min_two(a_list)
    if max1 - min1 == 1:
        print(count)
        exit()
    else:
        p1 = max1 - max2
        p2 = min2 - min1
        if p1 <= p2:
            count += p1
            i = a_list.index(max1)
            a_list[i] -= p1
            j = a_list.index(min1)
            a_list[j] += p1
        else:
            count += p2
            i = a_list.index(min1)
            a_list[i] += p2
            j = a_list.index(max1)
            a_list[j] -= p2

# %%
n = int(input())
a_list = [*map(int, input().split())]
count = 0

def get_max_two(l):
    # リストを降順にソートして最も大きな値と2番目に大きな値を取得
    sorted_list = sorted(l, reverse=True)
    max_value = sorted_list[0]
    second_max_value = sorted_list[1]
    return max_value, second_max_value

def get_min_two(l):
    # リストを昇順にソートして最も小さな値と2番目に小さな値を取得
    sorted_list = sorted(l)
    min_value = sorted_list[0]
    second_min_value = sorted_list[1]
    return min_value, second_min_value

while True:
    max1, max2 = get_max_two(a_list)
    min1, min2 = get_min_two(a_list)
#     print(max1, min1)
    if max1 - min1 == 1:
        print(count)
        exit()
    else:
        p1 = max1 - max2
        p2 = min2 - min1
        if p1 == 0:
            count += p2
            i = a_list.index(min1)
            a_list[i] += p2
            j = a_list.index(max1)
            a_list[j] -= p2
        
        elif p2 == 0:
            count += p1
            i = a_list.index(max1)
            a_list[i] -= p1
            j = a_list.index(min1)
            a_list[j] += p1
            
        elif p1 <= p2:
#             print("p2")
#             print(p1)
            count += p1
            i = a_list.index(max1)
            a_list[i] -= p1
            j = a_list.index(min1)
            a_list[j] += p1
#             print(a_list)
        else:
#             print("p1")
            count += p2
            i = a_list.index(min1)
            a_list[i] += p2
            j = a_list.index(max1)
            a_list[j] -= p2

    #print(a_list)  # a_listの値を表示して更新を確認
# Out:
# 4
# 4 7 3 7
# [4, 6, 4, 7]
# [5, 6, 4, 6]
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# [5, 5, 5, 6]
# 3
# ...

# %%
n = int(input())
a_list = [*map(int, input().split())]
count = 0
sorted_list = sorted(a_list)
a = sorted_list[0]
b = sorted_list[-1]
p = (b-a) // 2
for i in range(n//2):
    s = sorted_list[i]
    count += abs(p-s)
print(count)
# Out:
# 6
# 2 7 9 3 8 1
# 9

# %%
print((999999999-2)//2)
# Out:
# 499999998

# %%
n = int(input())
a = [*map(int, input().split())]
a = sorted(a)
sum_a = sum(a)
b = [sum_a // n for _ in range(n)]
for i in range(sum_a%n):
    b[n-1-i] += 1
ans = 0
for i in range(n):
    ans += abs(a[i]-b[i])
print(ans//2)
